# %%
# --- ABSA pipeline (San Francisco edition) ---

from pathlib import Path
import re, unicodedata, math, json, time
import numpy as np
import pandas as pd

# %pip install pyabsa pyarrow fastparquet

# [CHANGE vs Sowmya] repo-aware relative paths → use your data/ tree
ROOT = Path(__file__).resolve().parents[1] if "__file__" in globals() else Path.cwd().parent
PROC = ROOT / "data" / "processed"

REVIEWS_JSON     = PROC / "sf-sampled-reviews.json"  # <- your sampled SF reviews
RESTAURANTS_JSON = PROC / "sf-restaurants.json"      # <- SF places meta

# Outputs (kept under processed so other notebooks can consume)
OUT_BASE  = PROC / "sf_absa_outputs"
OUT_BASE.mkdir(parents=True, exist_ok=True)

OUT_USERS_ABSA_PARTS = OUT_BASE / "aspects_users_parts"    # chunked parquet parts (users)
OUT_ITEMS_ABSA_PARTS = OUT_BASE / "aspects_items_parts"    # chunked parquet parts (items)
OUT_USERS_ABSA_FULL  = OUT_BASE / "aspects_users_full.parquet"
OUT_ITEMS_ABSA_FULL  = OUT_BASE / "aspects_items_full.parquet"

OUT_USER_VEC = OUT_BASE / "user_aspect_vectors.parquet"
OUT_ITEM_VEC = OUT_BASE / "item_aspect_vectors.parquet"
OUT_COVER    = OUT_BASE / "aspect_bucket_coverage.csv"

pd.set_option("display.width", 140)
pd.set_option("display.max_colwidth", 120)

# [CHANGE vs Sowmya] one canonical ID normaliser used everywhere
def norm_id(x) -> str:
    if pd.isna(x): return ""
    s = str(x)
    s = unicodedata.normalize("NFKC", s)
    s = s.replace("\u200b","").replace("\u200c","").replace("\u200d","")
    s = re.sub(r"\s+", " ", s).strip()
    return s.lower()

print("Configured for SF JSONs")
print("Reviews:", REVIEWS_JSON)
print("Restaurants:", RESTAURANTS_JSON)
print("Outputs →", OUT_BASE)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: pyabsa in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: pyarrow in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (21.0.0)
# Requirement already satisfied: fastparquet in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (2024.11.0)
# Requirement already satisfied: findfile>=2.0.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (2.1.2)
# Requirement already satisfied: autocuda>=0.16 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (0.16)
# Requirement already satisfied: metric-visualizer>=0.9.6 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (0.9.17)
# Requirement already satisfied: boostaug>=2.3.5 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (2.3.5)
# Requirement already satisfied: spacy in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (3.8.7)
# Requirement already satisfied: networkx in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (3.5)
# Requirement already satisfied: seqeval in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (1.2.2)
# Requirement already satisfied: update-checker in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (0.18.0)
# Requirement already satisfied: typing-extensions in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (4.15.0)
# Requirement already satisfied: tqdm in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (4.67.1)
# Requirement already satisfied: pytorch-warmup in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (0.2.0)
# Requirement already satisfied: termcolor in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (3.2.0)
# Requirement already satisfied: gitpython in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (3.1.45)
# Requirement already satisfied: transformers>=4.18.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (4.44.2)
# Requirement already satisfied: torch>=1.0.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (2.2.2)
# Requirement already satisfied: sentencepiece in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (0.2.1)
# Requirement already satisfied: protobuf<4.0.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (3.20.3)
# Requirement already satisfied: pandas in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pyabsa) (2.3.3)
# Requirement already satisfied: numpy in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from fastparquet) (2.3.4)
# Requirement already satisfied: cramjam>=2.3 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from fastparquet) (2025.9.0)
# Requirement already satisfied: packaging in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from fastparquet) (25.0)
# Requirement already satisfied: matplotlib>=3.6.3 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (3.10.7)
# Requirement already satisfied: tikzplotlib in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (0.10.1)
# Requirement already satisfied: scipy in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (1.16.2)
# Requirement already satisfied: tabulate in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (0.9.0)
# Requirement already satisfied: natsort in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (8.4.0)
# Requirement already satisfied: click in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (8.3.0)
# Requirement already satisfied: openpyxl in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (3.1.5)
# Requirement already satisfied: xlsxwriter in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (3.2.9)
# Requirement already satisfied: scikit-learn in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (1.7.2)
# Requirement already satisfied: colorama in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from metric-visualizer>=0.9.6->pyabsa) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pandas->pyabsa) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pandas->pyabsa) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.3->metric-visualizer>=0.9.6->pyabsa) (1.17.0)
# Requirement already satisfied: filelock in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from torch>=1.0.0->pyabsa) (3.20.0)
# Requirement already satisfied: sympy in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from torch>=1.0.0->pyabsa) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from torch>=1.0.0->pyabsa) (3.1.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from transformers>=4.18.0->pyabsa) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from transformers>=4.18.0->pyabsa) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from transformers>=4.18.0->pyabsa) (2025.11.3)
# Requirement already satisfied: requests in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from transformers>=4.18.0->pyabsa) (2.32.5)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from transformers>=4.18.0->pyabsa) (0.6.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from transformers>=4.18.0->pyabsa) (0.19.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.18.0->pyabsa) (1.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from gitpython->pyabsa) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython->pyabsa) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.0.0->pyabsa) (3.0.3)
# Requirement already satisfied: et-xmlfile in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from openpyxl->metric-visualizer>=0.9.6->pyabsa) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from requests->transformers>=4.18.0->pyabsa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from requests->transformers>=4.18.0->pyabsa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from requests->transformers>=4.18.0->pyabsa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from requests->transformers>=4.18.0->pyabsa) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from scikit-learn->metric-visualizer>=0.9.6->pyabsa) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from scikit-learn->metric-visualizer>=0.9.6->pyabsa) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (0.20.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (2.12.3)
# Requirement already satisfied: setuptools in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (80.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from spacy->pyabsa) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy->pyabsa) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->pyabsa) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->pyabsa) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->pyabsa) (0.4.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy->pyabsa) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy->pyabsa) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy->pyabsa) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy->pyabsa) (14.2.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy->pyabsa) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy->pyabsa) (7.4.4)
# Requirement already satisfied: wrapt in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->pyabsa) (2.0.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->pyabsa) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->pyabsa) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->pyabsa) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->pyabsa) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from sympy->torch>=1.0.0->pyabsa) (1.3.0)
# Requirement already satisfied: webcolors in /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages (from tikzplotlib->metric-visualizer>=0.9.6->pyabsa) (25.10.0)
# Note: you may need to restart the kernel to use updated packages.
# Configured for SF JSONs
# Reviews: /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/data/processed/sf-sampled-reviews.json
# Restaurants: /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/data/processed/sf-restaurants.json
# Outputs → /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/data/processed/sf_absa_outputs

# %%
# [CHANGE vs Sowmya] no Colab drive / duckdb here; read local JSONL safely

def read_json_lines(path: Path) -> pd.DataFrame:
    rows = []
    with open(path, "r") as f:
        for line in f:
            if line.strip():
                rows.append(json.loads(line))
    return pd.DataFrame(rows)

reviews = read_json_lines(REVIEWS_JSON)
places  = read_json_lines(RESTAURANTS_JSON)

# enforce required columns (rename if your JSON uses slightly different keys)
rename_map = {
    "user_id": "user_id",
    "gmap_id": "gmap_id",
    "name": "name",
    "text": "text",
    "rating": "rating",
    "time": "time"
}
missing = [k for k in ["user_id","gmap_id","text","rating"] if k not in reviews.columns]
assert not missing, f"reviews JSON missing columns: {missing}"

# normalise IDs early (critical fix for Sowmya’s “6 warm users” issue)
reviews["user_id"] = reviews["user_id"].map(norm_id)
reviews["gmap_id"] = reviews["gmap_id"].map(norm_id)

if "gmap_id" in places.columns:
    places["gmap_id"] = places["gmap_id"].map(norm_id)

print(f"reviews: {len(reviews):,} rows | users={reviews.user_id.nunique():,} | items={reviews.gmap_id.nunique():,}")
# Out:
# reviews: 411,496 rows | users=131,972 | items=3,721

# %%
from pathlib import Path
import os, json
import numpy as np
import pandas as pd
import pyarrow as pa, pyarrow.parquet as pq
from pyabsa import ATEPCCheckpointManager
import torch
import pyabsa.tasks.AspectTermExtraction.models.__lcf__.fast_lcf_atepc as fast_lcf

os.environ.setdefault("PYABSA_HOME", str(OUT_BASE / "pyabsa_ckpt"))

# Smaller batches reduce odd shapes in PyABSA internals
BATCH_SIZE = 16
CKPT = "english"
CHUNK = 4000  # reviews per write (tweak for your RAM/CPU)

# --- PyABSA robustness patch v3: tolerate None / 0-D / ragged for labels & ids ---
def _to_2d_int64(x):
    """Coerce x into a padded 2-D int64 numpy array. Handles torch tensors, lists,
    ndarrays (incl. object dtype), 0-D scalars, and None."""
    if x is None:
        return np.zeros((1, 1), dtype=np.int64)
    try:
        arr = x.detach().cpu().numpy()  # torch path
    except Exception:
        arr = np.asarray(x, dtype=object)

    if arr is None:
        return np.zeros((1, 1), dtype=np.int64)
    if np.ndim(arr) == 0:
        try:
            v = arr.item()
        except Exception:
            v = None
        if v is None or (isinstance(v, float) and np.isnan(v)):
            v = 0
        else:
            try:
                v = int(v)
            except Exception:
                v = 0
        arr = np.array([[v]], dtype=object)
    elif np.ndim(arr) == 1:
        arr = np.array([arr], dtype=object)

    rows = []
    for row in arr:
        r = np.asarray(row, dtype=object)
        if r.ndim == 0:
            rows.append(np.array([0], dtype=np.int64))
            continue
        cleaned = []
        for el in np.ravel(r):
            if el is None or (isinstance(el, float) and np.isnan(el)):
                cleaned.append(0)
            else:
                try:
                    cleaned.append(int(el))
                except Exception:
                    cleaned.append(0)
        rows.append(np.array(cleaned, dtype=np.int64))

    maxlen = max((len(r) for r in rows), default=1)
    out = np.zeros((len(rows), maxlen), dtype=np.int64)
    for i, r in enumerate(rows):
        out[i, :len(r)] = r
    return out

def _safe_get_batch_token_labels_bert_base_indices(self, labels):
    padded = _to_2d_int64(labels)
    sep_token = self.num_labels - 1
    for i in range(padded.shape[0]):
        row = padded[i]
        hits = np.where(row == sep_token)[0]
        sep_index = int(hits[0]) if hits.size else (len(row) - 1)
        if sep_index + 1 < len(row):
            row[sep_index + 1:] = 0
        padded[i] = row
    return torch.tensor(padded, dtype=torch.long).to(self.bert4global.device)

def _safe_get_ids_for_local_context_extractor(self, text_indices):
    ids2d = _to_2d_int64(text_indices)
    return torch.tensor(ids2d, dtype=torch.long).to(self.bert4global.device)

# Apply monkey patches
fast_lcf.FAST_LCF_ATEPC.get_batch_token_labels_bert_base_indices = _safe_get_batch_token_labels_bert_base_indices
fast_lcf.FAST_LCF_ATEPC.get_ids_for_local_context_extractor     = _safe_get_ids_for_local_context_extractor

# Build extractor AFTER patching
extractor = ATEPCCheckpointManager.get_aspect_extractor(
    checkpoint=CKPT, auto_device=True, force_download=False, batch_size=BATCH_SIZE
)

# Per-item fallback so one bad sample doesn’t nuke a chunk
def safe_extract(texts: list[str]):
    try:
        return extractor.extract_aspect(texts, pred_sentiment=True, print_result=False, save_result=False)
    except Exception:
        out = []
        for t in texts:
            try:
                r = extractor.extract_aspect([t], pred_sentiment=True, print_result=False, save_result=False)
                out.append(r if isinstance(r, list) else [r])
            except Exception:
                out.append([{}])
        return out

def extract_to_parts(df: pd.DataFrame, id_cols: list[str], out_dir: Path):
    out_dir.mkdir(parents=True, exist_ok=True)
    wrote, total = 0, len(df)

    # Prefilter pathological texts (blank/ultra-short)
    df = df.assign(text=df["text"].astype(str).str.replace(r"\s+", " ", regex=True).str.strip())
    df = df[df["text"].str.len() >= 3].reset_index(drop=True)
    total = len(df)

    for start in range(0, total, CHUNK):
        stop = min(total, start + CHUNK)
        part = out_dir / f"part-{start:09d}.parquet"
        if part.exists():
            continue

        batch = df.iloc[start:stop].reset_index(drop=True).copy()
        texts = batch["text"].astype(str).tolist()

        # robust call
        res = safe_extract(texts)

        rows = []
        for i, r in enumerate(res):
            # robustly unwrap PyABSA result
            d = None
            if isinstance(r, dict) and "sentence" in r:
                d = r
            elif isinstance(r, dict) and "result" in r and r["result"]:
                d = r["result"][0]
            elif isinstance(r, list) and r:
                cand = r[0]
                if isinstance(cand, dict) and ("sentence" in cand or "result" in cand or "tokens" in cand):
                    d = cand

            if not d:
                continue

            tokens   = d.get("tokens", [])
            aspects  = d.get("aspect", [])
            pos      = d.get("position", [])
            sents    = d.get("sentiment", [])
            confs    = d.get("confidence", [None] * len(aspects))

            # Normalize container types
            if not isinstance(aspects, (list, tuple)):  aspects = [aspects]
            if not isinstance(pos, (list, tuple)):      pos = [pos]
            if not isinstance(sents, (list, tuple)):    sents = [sents]

            for k in range(min(len(aspects), len(pos), len(sents))):
                span_k = pos[k]
                span = span_k if isinstance(span_k, (list, tuple)) else [span_k]
                span = [int(x) for x in span if x is not None] or [0, 0]
                i0, i1 = (min(span), max(span)) if span else (0, 0)

                aspect_text = " ".join(tokens[i0:i1+1]) if tokens and 0 <= i0 <= i1 < len(tokens) else str(aspects[k])
                win0, win1 = max(0, i0-6), min(len(tokens), i1+7) if tokens else (0, 0)
                evidence = " ".join(tokens[win0:win1]) if tokens else aspect_text

                row = {
                    "aspect": aspect_text,
                    "sentiment": sents[k],
                    "confidence": confs[k] if confs else None,
                    "evidence": evidence,
                    "position": json.dumps(span),
                    "text": batch.loc[i, "text"],
                }
                for c in id_cols:
                    row[c] = batch.loc[i, c]
                rows.append(row)

        # write even if rows is empty (creates a small part file; harmless)
        pq.write_table(pa.Table.from_pylist(rows), part)
        wrote += len(rows)
    return wrote

# Users: keep user_id + gmap_id to allow (u,i) grouping later if needed
u_cols = ["user_id", "gmap_id", "text"]
i_cols = ["gmap_id", "text"]

print("Extracting user-aspects…")
wrote_u = extract_to_parts(reviews[u_cols], id_cols=["user_id","gmap_id"], out_dir=OUT_USERS_ABSA_PARTS)
print("Extracting item-aspects…")
wrote_i = extract_to_parts(reviews[i_cols], id_cols=["gmap_id"], out_dir=OUT_ITEMS_ABSA_PARTS)

# combine parts → *_full.parquet
def concat_parts(src_dir: Path, out_file: Path):
    parts = sorted(src_dir.glob("part-*.parquet"))
    writer = None; total = 0
    for p in parts:
        tbl = pq.read_table(p)
        if writer is None:
            writer = pq.ParquetWriter(out_file, tbl.schema)
        writer.write_table(tbl); total += tbl.num_rows
    if writer: writer.close()
    return total

tot_u = concat_parts(OUT_USERS_ABSA_PARTS, OUT_USERS_ABSA_FULL)
tot_i = concat_parts(OUT_ITEMS_ABSA_PARTS, OUT_ITEMS_ABSA_FULL)
print(f"users aspects rows: {tot_u:,}  | items aspects rows: {tot_i:,}")
# Out:
# [2025-11-05 20:09:18] (2.4.1) ********** Available ATEPC model checkpoints for Version:2.4.1 (this version) **********
# [2025-11-05 20:09:18] (2.4.1) ********** Available ATEPC model checkpoints for Version:2.4.1 (this version) **********
# [2025-11-05 20:09:18] (2.4.1) Downloading checkpoint:english
# [2025-11-05 20:09:18] (2.4.1) Notice: The pretrained model are used for testing, it is recommended to train the model on your own custom datasets
# [2025-11-05 20:09:18] (2.4.1) Checkpoint already downloaded, skip
# [2025-11-05 20:09:18] (2.4.1) Load aspect extractor from checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43
# [2025-11-05 20:09:18] (2.4.1) config: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43/fast_lcf_atepc.config
# [2025-11-05 20:09:18] (2.4.1) state_dict: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43/fast_lcf_atepc.state_dict
# [2025-11-05 20:09:18] (2.4.1) model: None
# [2025-11-05 20:09:18] (2.4.1) tokenizer: checkpoints/ATEPC_ENGLISH_CHECKPOINT/fast_lcf_atepc_English_cdw_apcacc_82.36_apcf1_81.89_atef1_75.43/fast_lcf_atepc.tokenizer
# [2025-11-05 20:09:18] (2.4.1) Set Model Device: cpu
# [2025-11-05 20:09:18] (2.4.1) Device Name: Unknown
# /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /Users/kienanana/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Extracting user-aspects…
# preparing ate inference dataloader: 100%|██████████| 4000/4000 [00:02<00:00, 1911.95it/s]
# extracting aspect terms:   0%|          | 0/125 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 140
#     137 i_cols = ["gmap_id", "text"]
#     139 print("Extracting user-aspects…")
# --> 140 wrote_u = extract_to_parts(reviews[u_cols], id_cols=["user_id","gmap_id"], out_dir=OUT_USERS_ABSA_PARTS)
#     141 print("Extracting item-aspects…")
#     142 wrote_i = extract_to_parts(reviews[i_cols], id_cols=["gmap_id"], out_dir=OUT_ITEMS_ABSA_PARTS)
#
# Cell In[32], line 93, in extract_to_parts(df, id_cols, out_dir)
#      91 batch = df.iloc[start:stop].reset_index(drop=True).copy()
#      92 texts = batch["text"].astype(str).tolist()
# ---> 93 res = extractor.extract_aspect(texts, pred_sentiment=True, print_result=False, save_result=False)
#      95 rows = []
#      96 for i, r in enumerate(res):
#      97     # robustly unwrap PyABSA result
#
# File ~/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages/pyabsa/tasks/AspectTermExtraction/prediction/aspect_extractor.py:248, in AspectExtractor.extract_aspect(self, inference_source, save_result, print_result, pred_sentiment, **kwargs)
#     226 def extract_aspect(
#     227     self,
#     228     inference_source: Union[List[Path], list, str],
#    (...)    232     **kwargs
#     233 ):
#     234     """
#     235     Extract aspects and their corresponding polarities from a list of input files.
#     236
#    (...)    246         The predicted aspects and their corresponding polarities.
#     247     """
# --> 248     return self.batch_predict(
#     249         inference_source, save_result, print_result, pred_sentiment, **kwargs
#     250     )
#
# File ~/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages/pyabsa/tasks/AspectTermExtraction/prediction/aspect_extractor.py:312, in AspectExtractor.batch_predict(self, target_file, save_result, print_result, pred_sentiment, **kwargs)
#     307     raise ValueError(
#     308         "Please run inference using examples list or inference dataset path (list)!"
#     309     )
#     311 if target_file:
# --> 312     extraction_res, sentence_res = self._extract(target_file)
#     313     if not pred_sentiment:
#     314         filtered_res = []
#
# File ~/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages/pyabsa/tasks/AspectTermExtraction/prediction/aspect_extractor.py:475, in AspectExtractor._extract(self, examples)
#     473 l_mask = l_mask.to(self.config.device)
#     474 with torch.no_grad():
# --> 475     ate_logits, apc_logits = self.model(
#     476         input_ids_spc,
#     477         token_type_ids=segment_ids,
#     478         attention_mask=input_mask,
#     479         labels=None,
#     480         polarity=polarity,
#     481         valid_ids=valid_ids,
#     482         attention_mask_label=l_mask,
#     483     )
#     484 if self.config.use_bert_spc:
#     485     label_ids = self.model.get_batch_token_labels_bert_base_indices(
#     486         label_ids
#     487     )
#
# File ~/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/SCHOOL/Y3S1/BT4222/PROJECT/.venv/lib/python3.11/site-packages/pyabsa/tasks/AspectTermExtraction/models/__lcf__/fast_lcf_atepc.py:74, in FAST_LCF_ATEPC.forward(self, input_ids_spc, token_type_ids, attention_mask, labels, polarity, valid_ids, attention_mask_label, lcf_cdm_vec, lcf_cdw_vec)
#      72 if self.config.use_bert_spc:
#      73     input_ids = self.get_ids_for_local_context_extractor(input_ids_spc)
# ---> 74     labels = self.get_batch_token_labels_bert_base_indices(labels)
#      75     global_context_out = self.bert4global(
#      76         input_ids=input_ids, attention_mask=attention_mask
#      77     )["last_hidden_state"]
#      78 else:
#
# Cell In[32], line 57, in _safe_get_batch_token_labels_bert_base_indices(self, labels)
#      56 def _safe_get_batch_token_labels_bert_base_indices(self, labels):
# ---> 57     padded = _to_2d_int64(labels)
#      59     # Find SEP (num_labels-1) per row; if none, use last index
#      60     sep_token = self.num_labels - 1
#
# Cell In[32], line 31, in _to_2d_int64(x)
#      28     arr = np.array([[0]], dtype=np.int64)
#      29 elif np.ndim(arr) == 0:
#      30     # scalar -> [[scalar]]
# ---> 31     v = int(arr) if np.size(arr) else 0
#      32     arr = np.array([[v]], dtype=object)
#      33 elif np.ndim(arr) == 1:
#      34     # 1-D -> [row]
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
# Canonical 8 aspect buckets (editable)
ASPECT_BUCKETS = {
    "food":       ["food","taste","flavor","dish","noodle","sushi","pizza","burger","taco","spicy","fresh","broth","steak","dessert","menu","ramen","bbq"],
    "service":    ["service","staff","waiter","waitress","server","attentive","rude","friendly","manager","host","hosts","hostess"],
    "price":      ["price","cost","value","cheap","expensive","affordable","overpriced","worth","deal","pricing"],
    "ambience":   ["ambience","atmosphere","vibe","noise","music","decor","seating","lighting","crowded","cozy","environment"],
    "cleanliness":["clean","dirty","bathroom","restroom","sanitary","hygiene","messy","filthy"],
    "portion":    ["portion","size","serving","amount","quantity","share","big","small"],
    "wait_time":  ["wait","queue","delay","slow","fast","quick","prompt","line","service time"],
    "location":   ["location","parking","nearby","distance","convenient","access","walk","drive"],
}

# quick regex/lexicon mapper (fast and dependency-free)
PUNCT_RX = re.compile(r"[^\w\s\-]")
STOP = set(["the","a","an","and","or","in","at","of","to","for","on","is","are","was","were","very","really","so"])
LEXICON = {w: b for b, words in ASPECT_BUCKETS.items() for w in words}

def normalize_term(term: str) -> str:
    t = str(term).lower().strip()
    t = PUNCT_RX.sub(" ", t)
    t = re.sub(r"\s+", " ", t)
    return t

def tokenize_keep_heads(s: str):
    toks = [w.strip("-") for w in s.split() if w and w not in STOP]
    return toks[:2] if len(toks) > 1 else toks

def map_term_to_bucket(term: str):
    t = normalize_term(term)
    for tok in tokenize_keep_heads(t):
        if tok in LEXICON:
            return LEXICON[tok]
    return None

# %%
# Load extracted aspects (from Cell 4 or precomputed)
assert OUT_USERS_ABSA_FULL.exists() and OUT_ITEMS_ABSA_FULL.exists(), \
    "Missing ABSA outputs. Run Cell 4 or drop existing *_full.parquet into OUT_BASE."

U_ABSA = pd.read_parquet(OUT_USERS_ABSA_FULL)
I_ABSA = pd.read_parquet(OUT_ITEMS_ABSA_FULL)

# [CHANGE vs Sowmya] enforce clean IDs here too
for col in (c for c in ["user_id","gmap_id"] if c in U_ABSA.columns):
    U_ABSA[col] = U_ABSA[col].map(norm_id)
for col in (c for c in ["gmap_id"] if c in I_ABSA.columns):
    I_ABSA[col] = I_ABSA[col].map(norm_id)

# Keep only rows with valid sentiment (Positive/Negative/Neutral)
U_ABSA["sentiment"] = U_ABSA["sentiment"].astype(str).str.title()
I_ABSA["sentiment"] = I_ABSA["sentiment"].astype(str).str.title()

print("U_ABSA rows:", len(U_ABSA), "| I_ABSA rows:", len(I_ABSA))

# %%
# sentiment → numeric
def to_numeric_sentiment(x):
    s = str(x).strip().lower()
    if s in ("positive","pos","+1","1"): return 1.0
    if s in ("negative","neg","-1"):     return -1.0
    return 0.0

def aggregate_aspect_vectors(df: pd.DataFrame, by: str) -> pd.DataFrame:
    buckets = list(ASPECT_BUCKETS.keys())
    stats = {}
    for key, g in df.groupby(by):
        row = {"key": key}
        for b in buckets:
            sub = g[g["bucket"] == b]
            w = float(sub["confidence"].fillna(1.0).sum())
            score = float((sub["confidence"].fillna(1.0) * sub["polarity"]).sum() / w) if w > 0 else 0.0
            row[f"{b}_sent"] = score
            row[f"{b}_cnt"]  = int(len(sub))
        row["total_mentions"] = int(sum(row[f"{b}_cnt"] for b in buckets))
        stats[key] = row
    out = pd.DataFrame(stats.values()).rename(columns={"key": by})
    return out

# map terms to buckets
def prepare_absa(df: pd.DataFrame, require_user: bool) -> pd.DataFrame:
    need = ["aspect","sentiment"]
    if require_user: need += ["user_id","gmap_id"]
    else:            need += ["gmap_id"]
    missing = [c for c in need if c not in df.columns]
    assert not missing, f"ABSA file missing: {missing}"

    out = df[need + (["confidence"] if "confidence" in df.columns else [])].copy()
    out["bucket"]   = out["aspect"].map(map_term_to_bucket)
    out["polarity"] = out["sentiment"].map(to_numeric_sentiment)
    out["confidence"] = pd.to_numeric(out.get("confidence", 1.0), errors="coerce").fillna(1.0).clip(0,1)
    out = out[out["bucket"].notna()].reset_index(drop=True)
    return out

U_map = prepare_absa(U_ABSA, require_user=True)
I_map = prepare_absa(I_ABSA, require_user=False)

# [CHANGE vs Sowmya] keep neutrals in the pool (polarity=0) so they don’t “erase” users/items completely
user_vecs = aggregate_aspect_vectors(U_map, by="user_id")
# items: pool aspects mentioned by users + those inferred per-place
I_pool = pd.concat([U_map[["gmap_id","bucket","polarity","confidence"]],
                    I_map[["gmap_id","bucket","polarity","confidence"]]], ignore_index=True)
item_vecs = aggregate_aspect_vectors(I_pool, by="gmap_id")

# Save
user_vecs.to_parquet(OUT_USER_VEC, index=False)
item_vecs.to_parquet(OUT_ITEM_VEC, index=False)

print("Saved:")
print(" -", OUT_USER_VEC)
print(" -", OUT_ITEM_VEC)

# Coverage report (for quick sanity)
cov = (pd.concat([U_map[["bucket"]], I_map[["bucket"]]]).value_counts()
       .rename_axis(["bucket"]).reset_index(name="n_terms"))
cov["share"] = cov["n_terms"] / cov["n_terms"].sum()
cov.to_csv(OUT_COVER, index=False)
cov.head(10)

# %%
# Support tiers (how much ABSA signal each entity has)
for df, key in [(user_vecs, "user_id"), (item_vecs, "gmap_id")]:
    df["support_tier"] = pd.cut(
        df["total_mentions"], bins=[0,2,5,10,999999], labels=["cold","light","medium","heavy"]
    ).astype(str)

print("Users by tier:\n", user_vecs["support_tier"].value_counts(normalize=True))
print("\nItems by tier:\n", item_vecs["support_tier"].value_counts(normalize=True))

# ID alignment with reviews universe — should be large, not “6”
U_keep = set(reviews["user_id"])
I_keep = set(reviews["gmap_id"])
print("\nAlignment:")
print("users in vectors ∩ reviews:", len(set(user_vecs["user_id"]) & U_keep))
print("items in vectors ∩ reviews:", len(set(item_vecs["gmap_id"]) & I_keep))

# quick heads
display(user_vecs.head(3))
display(item_vecs.head(3))
